# %% [markdown]
# <center><img src='https://drive.google.com/uc?id=1_utx_ZGclmCwNttSe40kYA6VHzNocdET' height="60"></center>
#
# AI TECH - Akademia Innowacyjnych Zastosowań Technologii Cyfrowych. Programu Operacyjnego Polska Cyfrowa na lata 2014-2020
# <hr>
#
# <center><img src='https://drive.google.com/uc?id=1BXZ0u3562N_MqCLcekI-Ens77Kk4LpPm'></center>
#
# <center>
# Projekt współfinansowany ze środków Unii Europejskiej w ramach Europejskiego Funduszu Rozwoju Regionalnego
# Program Operacyjny Polska Cyfrowa na lata 2014-2020,
# Oś Priorytetowa nr 3 "Cyfrowe kompetencje społeczeństwa" Działanie  nr 3.2 "Innowacyjne rozwiązania na rzecz aktywizacji cyfrowej"
# Tytuł projektu:  „Akademia Innowacyjnych Zastosowań Technologii Cyfrowych (AI Tech)”
#     </center>

# %% [markdown]
# # Simple linear regression
#
# In this exercise you will train a linear regression model via gradient descent in the simplest scenario, i.e. recreating an affine function.
#
# The setup is as follows:
# * we are given a set of pairs $(x, y)$, where $x$ represents the feature, and $y$ is the target,
# * our hypothesis is $h(x) = ax + b$,
# * we will use the dataset consisting of set of pairs to figure out the right values for $a$ and $b$,
# * to do so we will optimize the loss function: $J(a,b) = \frac{1}{n}\sum_{i=1}^n (y_i - h(x_i))^2$,
# * with the loss function in hand we can improve our guesses iteratively:
#     * $a^{t+1} = a^t - \text{step_size} \cdot \frac{\partial J(a,b)}{\partial a}$,
#     * $b^{t+1} = b^t - \text{step_size} \cdot \frac{\partial J(a,b)}{\partial b}$,
# * we can end the process after some predefined number of epochs (or when the changes are no longer meaningful).
#
# Let's start with creating the dataset.

# %%
import random
import numpy as np

_a = 0.3
_b = 0.5

f = lambda x: _a * x + _b # ground truth
g = lambda x: f(x) + random.gauss(0, 0.02) # a noisy version of f, (0.02)^2 = 0.0004 = sigma^2

# %%
n = 50 # number of examples

x = [random.random() for _ in range(n)] # features
ys = list(map(g, x)) # targets

ts = list(map(f, x)) # we don't get to see this

x = np.array(x)
y = np.array(ys)
t = np.array(ts)

# %% [markdown]
# Our goal is to recreate $f$. However, as reality can be harsh (and usually is) we only get to observe $g$. We observe it as a list of pairs $(x,y) \in \text{zip}(x, ys)$.
#
# Let's plot the data. We will use the `plotly` library to make the plots interactive, which allows for easier inspection of data.

# %%
# !pip install --upgrade plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (6.3.1)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from plotly) (2.9.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (25.0)

# %%
import plotly.graph_objects as go
import plotly.express as px

fig = px.scatter(x=x, y=ys)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="dd88c125-8229-48fa-b4af-55db0f48c2b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("dd88c125-8229-48fa-b4af-55db0f48c2b4")) {                    Plotly.newPlot(                        "dd88c125-8229-48fa-b4af-55db0f48c2b4",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"RLRFQwBFwj9crBLQP5btPyIKquqqZe8\u002f7jGXl+aR2T99sqyRqNDqP0FpUCgj9e4\u002feNI3twoU2D8pijrtd+jiP2AFI2rq4J8\u002fUIi1OTOOpD+BmrQ32xviP87OW7t1Nt4\u002fr30FZLv84T\u002facZS1dVXpP5J1JD85At0\u002fdhjJKTBZ7T\u002fggHa08pveP9TNAc50dsk\u002fqBhsDdsu5j8K72adkFrjP\u002fQnnYATC+o\u002fsCkukBm3uj\u002fEw0k87nDiP5LCkyvqqO0\u002fyB\u002fNpt1n4T8tqKhDn6rpP6AoAxUXlJI\u002fmQ\u002f6o4Un7T\u002fNweheNajrPygOiQXD6t8\u002fqB5EdN6xsz++39qWQqToP0DFdcNRILA\u002fnkGCoN\u002fu7z8pF5zcZVXkP\u002fh7PnJule4\u002fGtyOrFdR0T9yVjZQQe7YP8zyNPHAftI\u002fXC4mPFxF4D9zJAVRVLnrP0Zz3P4Pueg\u002fqM2qBp4u4j+dA9Q3eabsPxwBdiVBF8I\u002fahHyF\u002fW71j8uRamUfszbP2JjopHS5dA\u002fEIZPFJgEsT8wFvvZs0zNPw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"orfFWyHC4T\u002fNJyFt\u002fTrpPzURiBV53eg\u002fZpzC9gBJ5T8f3QggXpboP6ZWbiV5\u002feg\u002fusGvVMyw4z+tgSAZe5vlP6tHx+iSiOE\u002fhMdDLO+h4D+Q0VLBQcXmP7Y9M7EJ8+M\u002fYF0yeDl15D+pjSKsg1\u002foP0R3SsKFd+Q\u002fH6BgqhVe6T+v7GB3G0\u002fkPxHB4cnuleI\u002f+0pNu0cg5j\u002fFXnBBSoLlPw53\u002fqjGjuc\u002fETIwrKPU4D81W1zdZUPlP73+WJjJY+k\u002fBrA3ahB\u002f5T9oAwogbvLnPzdEkJDtouA\u002f5\u002fN3eVBc6T\u002fASTrT6K7oP8QaCq0AReU\u002fL3WebIZv3z+pp79M3t7nP1hc23E+eOE\u002fa5omC05O6T\u002fp5aVU1MvlP0ua18FU8+g\u002fJkBS3CvH4j+efKzTz03kP+5k6o6SfuI\u002fITO7EXwa5D+tN8vDuKjnP\u002fTEJOU9Y+c\u002fNi32TgBH5T9VGC4biJnoP96Q3HFhVeI\u002fIFnhsuGP4j8kM7fGfFvkPyWvIUCscuI\u002fN++NsYRN4T\u002f7Shqaa+nhPw=="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"sur ...

# %%
import numpy as np

def mse_loss(y, p):
    assert len(y) == len(p)

    ### YOUR CODE BEGINS HERE ###
    n=len(y)
    return sum((y-p)**2)/n
    ### YOUR CODE ENDS HERE ###

# %% [markdown]
# Please take a while to (roughly) guess the output before executing the cell below.

# %%
mse_loss(y, t)
# Out:
# np.float64(0.0003320077605081672)

# %% [markdown]
# Let's now implement the algorithm
#
# Hint: To make sure that you correctly compute the gradients, you can compute them numerically and compare the results.

# %%
a = 0. # our initial guess for _a
b = 0. # our initial guess for _b
lr = 0.5 # step size

n_epochs = 40 # number of passes over the training data

def predict(a, b, x=x):
    return a*x + b

def evaluate(a, b, x=x, y=y):
    return mse_loss(y, predict(a, b, x))

losses = [evaluate(a, b)]

for i in range(n_epochs):
    #############################
    # TODO: Fill in the details #
    #############################
    ### YOUR CODE BEGINS HERE ###
    a_grad = 2/n*sum(a*x**2+(-y+b)*x)
    b_grad = 2/n*(n*b - sum(y) + a*sum(x))
    a = a - lr*a_grad
    b = b - lr*b_grad
    ### YOUR CODE ENDS HERE ###

    loss = evaluate(a, b)
    losses.append(loss)
    print(f'Iter: {i:>3} Loss: {loss:8.8f} a: {a:8.5f}, b: {b:8.5f}')
# Out:
# Iter:   0 Loss: 0.04209318 a:  0.38020, b:  0.66323
# Iter:   1 Loss: 0.00421107 a:  0.26394, b:  0.46067
# Iter:   2 Loss: 0.00067536 a:  0.29935, b:  0.52261
# Iter:   3 Loss: 0.00034534 a:  0.28844, b:  0.50374
# Iter:   4 Loss: 0.00031453 a:  0.29168, b:  0.50956
# Iter:   5 Loss: 0.00031164 a:  0.29061, b:  0.50783
# Iter:   6 Loss: 0.00031137 a:  0.29086, b:  0.50840
# Iter:   7 Loss: 0.00031134 a:  0.29071, b:  0.50826
# Iter:   8 Loss: 0.00031133 a:  0.29069, b:  0.50834
# Iter:   9 Loss: 0.00031132 a:  0.29064, b:  0.50835
# Iter:  10 Loss: 0.00031132 a:  0.29060, b:  0.50838
# Iter:  11 Loss: 0.00031131 a:  0.29056, b:  0.50840
# Iter:  12 Loss: 0.00031131 a:  0.29052, b:  0.50843
# Iter:  13 Loss: 0.00031131 a:  0.29049, b:  0.50845
# Iter:  14 Loss: 0.00031130 a:  0.29046, b:  0.50846
# Iter:  15 Loss: 0.00031130 a:  0.29043, b:  0.50848
# Iter:  16 Loss: 0.00031130 a:  0.29040, b:  0.50850
# Iter:  17 Loss: 0.00031130 a:  0.29037, b:  0.50851
# Iter:  18 Loss: 0.00031130 a:  0.29035, b:  0.50852
# Iter:  19 Loss: 0.00031130 a:  0.29033, b:  0.50854
# Iter:  20 Loss: 0.00031129 a:  0.29031, b:  0.50855
# Iter:  21 Loss: 0.00031129 a:  0.29029, b:  0.50856
# Iter:  22 Loss: 0.00031129 a:  0.29027, b:  0.50857
# Iter:  23 Loss: 0.00031129 a:  0.29025, b:  0.50858
# Iter:  24 Loss: 0.00031129 a:  0.29024, b:  0.50859
# Iter:  25 Loss: 0.00031129 a:  0.29022, b:  0.50860
# Iter:  26 Loss: 0.00031129 a:  0.29021, b:  0.50860
# Iter:  27 Loss: 0.00031129 a:  0.29020, b:  0.50861
# Iter:  28 Loss: 0.00031129 a:  0.29019, b:  0.50862
# Iter:  29 Loss: 0.00031129 a:  0.29018, b:  0.50862
# Iter:  30 Loss: 0.00031129 a:  0.29017, b:  0.50863
# Iter:  31 Loss: 0.00031129 a:  0.29016, b:  0.50863
# Iter:  32 Loss: 0.00031129 a:  0.29015, b:  0.50864
# Iter:  33 Loss: 0.00031129 a:  0.29014, b:  0.50864
# Iter:  34 Loss: 0.00031129 a:  0.29013, b:  0.50865
# Iter:  35 Loss: 0.00031129 a:  0.29013, b:  0.50865
# Iter:  36 Loss: 0.00031129 a:  0.29012, b:  0.50866
# Iter:  37 Loss: 0.00031129 a:  0.29012, b:  0.50866
# Iter:  38 Loss: 0.00031129 a:  0.29011, b:  0.50866
# Iter:  39 Loss: 0.00031129 a:  0.29011, b:  0.50866

# %%
fig = px.line(y=losses, labels={'y':'loss'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="de7f43b3-4211-412e-be51-163d38341646" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("de7f43b3-4211-412e-be51-163d38341646")) {                    Plotly.newPlot(                        "de7f43b3-4211-412e-be51-163d38341646",                        [{"hovertemplate":"x=%{x}\u003cbr\u003eloss=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":{"dtype":"i1","bdata":"AAECAwQFBgcICQoLDA0ODxAREhMUFRYXGBkaGxwdHh8gISIjJCUmJyg="},"xaxis":"x","y":{"dtype":"f8","bdata":"Otu\u002fDISr3D9AaHalPI2lP\u002f97Bn+gP3E\u002fe0PQjEwhRj\u002faP3wk3aE2P8hQ2GbtnDQ\u002fbQ9CiohsND9FuEj042c0PzvQvidZZzQ\u002fQDdhJjRnND+GvK\u002fvG2c0P8sA0cEHZzQ\u002fOwsHaPZmND8aGZ5v52Y0P2Qrv4PaZjQ\u002fF5eBXM9mND+jJfO7xWY0P9Z0nmy9ZjQ\u002ffPteQLZmND9WhmAPsGY0P2wIQreqZjQ\u002fg7RWGqZmND\u002ftNQEfomY0P2J1Ja+eZjQ\u002fPtStt5tmND\u002fHMyEomWY0P5B8R\u002fKWZjQ\u002fOaraCZVmND+UpEJkk2Y0P+5rWviRZjQ\u002fX1I9vpBmND9KJxuvj2Y0P3hiEsWOZjQ\u002fRnwP+41mND+MvbBMjWY0Py7rLbaMZjQ\u002f3UVDNIxmND8YaR\u002fEi2Y0P8SlU2OLZjQ\u002fb4DGD4tmND\u002faCKjHimY0Pw=="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{ ...

# %% [markdown]
# Let's now visually asses how we do on training data

# %%
fig = go.Figure()

fig = px.scatter(x=x, y=y)
dense_x = np.linspace(np.min(x), np.max(x), 100)
fig.add_trace(go.Scatter(x=dense_x, y=predict(a, b, dense_x), name='linear fit', mode='lines'))
fig.add_trace(go.Scatter(x=x, y=t, name='y without noise', mode='markers'))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="9cc715eb-b4b0-4f98-a76f-b10eef8c5dba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9cc715eb-b4b0-4f98-a76f-b10eef8c5dba")) {                    Plotly.newPlot(                        "9cc715eb-b4b0-4f98-a76f-b10eef8c5dba",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"RLRFQwBFwj9crBLQP5btPyIKquqqZe8\u002f7jGXl+aR2T99sqyRqNDqP0FpUCgj9e4\u002feNI3twoU2D8pijrtd+jiP2AFI2rq4J8\u002fUIi1OTOOpD+BmrQ32xviP87OW7t1Nt4\u002fr30FZLv84T\u002facZS1dVXpP5J1JD85At0\u002fdhjJKTBZ7T\u002fggHa08pveP9TNAc50dsk\u002fqBhsDdsu5j8K72adkFrjP\u002fQnnYATC+o\u002fsCkukBm3uj\u002fEw0k87nDiP5LCkyvqqO0\u002fyB\u002fNpt1n4T8tqKhDn6rpP6AoAxUXlJI\u002fmQ\u002f6o4Un7T\u002fNweheNajrPygOiQXD6t8\u002fqB5EdN6xsz++39qWQqToP0DFdcNRILA\u002fnkGCoN\u002fu7z8pF5zcZVXkP\u002fh7PnJule4\u002fGtyOrFdR0T9yVjZQQe7YP8zyNPHAftI\u002fXC4mPFxF4D9zJAVRVLnrP0Zz3P4Pueg\u002fqM2qBp4u4j+dA9Q3eabsPxwBdiVBF8I\u002fahHyF\u002fW71j8uRamUfszbP2JjopHS5dA\u002fEIZPFJgEsT8wFvvZs0zNPw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"orfFWyHC4T\u002fNJyFt\u002fTrpPzURiBV53eg\u002fZpzC9gBJ5T8f3QggXpboP6ZWbiV5\u002feg\u002fusGvVMyw4z+tgSAZe5vlP6tHx+iSiOE\u002fhMdDLO+h4D+Q0VLBQcXmP7Y9M7EJ8+M\u002fYF0yeDl15D+pjSKsg1\u002foP0R3SsKFd+Q\u002fH6BgqhVe6T+v7GB3G0\u002fkPxHB4cnuleI\u002f+0pNu0cg5j\u002fFXnBBSoLlPw53\u002fqjGjuc\u002fETIwrKPU4D81W1zdZUPlP73+WJjJY+k\u002fBrA3ahB\u002f5T9oAwogbvLnPzdEkJDtouA\u002f5\u002fN3eVBc6T\u002fASTrT6K7oP8QaCq0AReU\u002fL3WebIZv3z+pp79M3t7nP1hc23E+eOE\u002fa5omC05O6T\u002fp5aVU1MvlP0ua18FU8+g\u002fJkBS3CvH4j+efKzTz03kP+5k6o6SfuI\u002fITO7EXwa5D+tN8vDuKjnP\u002fTEJOU9Y+c\u002fNi32TgBH5T9VGC4biJnoP96Q3HFhVeI\u002fIFnhsuGP4j8kM7fGfFvkPyWvIUCscuI\u002fN++NsYRN4T\u002f7Shqaa+nhPw=="},"yaxis":"y","type":"scatter"},{"mode":"lines","name":"linear fit","x":{"dtype":"f8","bdata":"oCgDFReUkj+my8WlbracP1Y3RBtjbKM\u002f2Iil4459qD9b2gasuo6tP+8VNDrzT7E\u002fsL5kHonYsz9yZ5UCH2G2PzMQxua06bg\u002f9Lj2ykpyuz+2YSev4Pq9PzwFrEm7QcA\u002fnFnEOwaGwT\u002f9rdwtUcrCP14C9R+cDsQ\u002fvlYNEudSxT8fqyUEMpfGP4D\u002fPfZ828c\u002f4FNW6McfyT9BqG7aEmTKP6L8hsxdqMs\u002fAlGfvqjszD9jpbew8zDOP8T5z6I+dc8\u002fEid0ysRc0D9CUYBD6v7QP3N7jLwPodE\u002fo6WYNTVD0j\u002fUz6SuWuXSPwT6sCeAh9M\u002fNCS9oKUp1D9lTskZy8vUP5V41ZLwbdU\u002fxaLhCxYQ1j\u002f2zO2EO7LWPyb3+f1gVNc\u002fViEGd4b21z+HSxLwq5jYP7d1HmnROtk\u002f558q4vbc2T8YyjZbHH\u002faP0j0QtRBIds\u002feB5PTWfD2z+pSFvGjGXcP9lyZz+yB90\u002fCZ1zuNep3T86x38x\u002fUveP2rxi6oi7t4\u002fmhuYI0iQ3z\u002fmIlLONhngP\u002f432IpJauA\u002fFk1eR1y74D8uYuQDbwzhP0Z3asCBXeE\u002fXozwfJSu4T92oXY5p\u002f\u002fhP4+2\u002fPW5UOI\u002fp8uCssyh4j+\u002f4Ahv3\u002fLiP9f1jivyQ+M\u002f7woV6ASV4z8HIJukF+bjPyA1IWEqN+Q\u002fOEqnHT2I5D9QXy3aT9nkP2h0s5ZiKuU\u002fgIk5U3V75T+Znr8PiMzlP7GzRcyaHeY\u002fycjLiK1u5j\u002fh3VFFwL\u002fmP\u002fny1wHTEOc\u002fEQhevuVh5z8qHeR6+LLnP0IyajcLBOg\u002fWkfw8x1V6D9yXHawMKboP4px\u002fGxD9+g\u002fooaCKVZI6T+7mwjmaJnpP9OwjqJ76uk\u002f68UUX4476j8D25oboYzqPxvwINiz3eo\u002fMwWnlMYu6z9MGi1R2X\u002frP2Qvsw3s0Os\u002ffEQ5yv4h7D+UWb+GEXPsP6xuRUMkxOw\u002fxIPL\u002fzYV7T\u002fdmFG8SWbtP\u002fWt13hct+0\u002fDcNdNW8I7j8l2OPxgVnuPz3taa6Uqu4\u002fVQLwaqf77j9uF3YnukzvP4Ys\u002fOPMne8\u002fnkGCoN\u002fu7z8="},"y":{"dtype":"f8","bdata":"BxA+fRly4D+RDtKMnongPxoNZpwjoeA\u002fpAv6q6i44D8uCo67LdDgP7gIIsuy5+A\u002fQQe22jf\u002f4D\u002fLBUrqvBbhP1UE3vlBLuE\u002f3gJyCcdF4T9oAQYZTF3hP\u002fL\u002fmSjRdOE\u002ffP4tOFaM4T8F\u002fcFH26PhP4\u002f7VVdgu+E\u002fGfrpZuXS4T+j+H12aurhPyz3EYbvAeI\u002ftvWllXQZ4j9A9Dml+ ...

# %% [markdown]
# Let's check our implementation vs. the one in sklearn and numpy.

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

X = np.array(x).reshape((len(x), 1))
regr = LinearRegression()
regr.fit(X, ys) # training

sk_a = float(regr.coef_)
sk_b = regr.intercept_
sk_loss = mse_loss(ys, regr.predict(X))

print(f'Loss: {sk_loss:8.8f} a: {sk_a:8.5f}, b: {sk_b:8.5f}')
# Out:
# Loss: 0.00031129 a:  0.29004, b:  0.50870
# /tmp/ipython-input-2743703387.py:8: DeprecationWarning:
#
# Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)

# %%
z = np.polyfit(x=x, y=ys, deg=1)
print(z)
f = np.poly1d(z)
print(f)
# Out:
# [0.29003913 0.50870277]
#
# 0.29 x + 0.5087

# %% [markdown]
# <center><img src='https://drive.google.com/uc?id=1BXZ0u3562N_MqCLcekI-Ens77Kk4LpPm'></center>
